# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
link = 'https://www.infinityfree.com/'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
response = requests.get(link, headers=headers)

# %%
if response.status_code == 200:
    soup = bs(response.text, 'html.parser')
    print(soup.prettify())
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-us">
#  <head>
#   <meta content="Hugo 0.111.3" name="generator"/>
#   <title>
#    Free Web Hosting with PHP and MySQL - InfinityFree
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="telephone=no" name="format-detection">
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html dir="ltr" lang="en-us">
#  <head>
#  <meta content="Hugo 0.111.3" name="generator"/>
#  <title>Free Web Hosting with PHP and MySQL - InfinityFree</title>
#  <meta charset="utf-8"/>
#  <meta content="telephone=no" name="format-detection">
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
list(soup.children)[0]
# Out:
# 'html'

# %%
list(soup.children)[1]
# Out:
# '\n'

# %%
html = list(soup.children)[2]

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <meta content="Hugo 0.111.3" name="generator"/>
#  <title>Free Web Hosting with PHP and MySQL - InfinityFree</title>
#  <meta charset="utf-8"/>
#  <meta content="telephone=no" name="format-detection">
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
head = list(html.children)[1]

# %%
list(head.children)[1]
# Out:
# <meta content="Hugo 0.111.3" name="generator"/>

# %%
title = list(head.children)[1]

# %%
data = title.get_text()

# %%
print(data)

# %%
soup.find_all('p')
# Out:
# [<p>PHP &amp; MySQL | No ads on your site | Over 500,000 websites</p>,
#  <p>
#  Our hosting was independently tested and found to be the fastest free hosting in the world.
#  </p>,
#  <p>
#  Uptime is our main priority, which is why we can proudly say we offer 99.9% uptime.
#  </p>,
#  <p>
#  InfinityFree is website hosting with no time limit, and no limit on the number of websites you can host.
#  </p>,
#  <p>
#  InfinityFree is completely free, no credit card required and no hidden fees.
#  </p>,
#  <p>
#  Your website is your own, we will never place advertisements on your website.
#  </p>,
#  <p>
#  Bring your own domain name or pick a free subdomain from 25+ extensions.
#  </p>,
#  <p>
#  InfinityFree includes everything you could possibly need to build your website,
#  no matter what kind of website you are working on.
#  </p>,
#  <p>
#  With full support for PHP and MySQL, InfinityFree is a great place to host WordPress.
# ...

# %%
pragraph_two_data = soup.find_all('p')[1].get_text()

# %%
print(pragraph_two_data)
# Out:
# Our hosting was independently tested and found to be the fastest free hosting in the world.

# %%
nabvbar_item_content = soup.find_all('li', class_='nav-item')
print(nabvbar_item_content)
# Out:
# [<li class="nav-item">
# <a class="nav-link" href="/">Free Hosting</a>
# </li>, <li class="nav-item">
# <a class="nav-link" href="/premium/">Premium Hosting</a>
# </li>, <li class="nav-item">
# <a class="nav-link" href="/website-builder/">Website Builder</a>
# </li>, <li class="nav-item">
# <a class="nav-link" href="https://forum.infinityfree.com/docs">Knowledge Base</a>
# </li>, <li class="nav-item">
# <a class="nav-link" href="https://forum.infinityfree.com">Support Forum</a>
# </li>]

# %%
nabvbar_item_content = soup.find_all('div', id='collapseOne')
print(nabvbar_item_content)
# Out:
# [<div aria-labelledby="headingOne" class="accordion-collapse collapse show" data-bs-parent="#faqAccordion" id="collapseOne">
# <div class="accordion-body">
# <p>
# Yes, you can host your website without having to pay. Ever.
# </p>
# </div>
# </div>]

# %%
selecting_h5_from_selector = soup.select("div h3")
print(selecting_h5_from_selector)
# Out:
# [<h3>Fastest Free Hosting</h3>, <h3>99.9% Uptime</h3>, <h3>Unlimited Hosting</h3>, <h3>Completely Free</h3>, <h3>No Ads on Your Site</h3>, <h3>Host Any Domain</h3>]

# %%
for h3 in selecting_h5_from_selector:
    print(h3.get_text(strip=True))
# Out:
# Fastest Free Hosting
# 99.9% Uptime
# Unlimited Hosting
# Completely Free
# No Ads on Your Site
# Host Any Domain

# %%
soup.find_all('a')
# Out:
# [<a href="https://www.enable-javascript.com/" target="_blank"><b>here</b></a>,
#  <a class="navbar-brand" href="/">
#  <picture>
#  <img alt="Free Web Hosting with PHP and MySQL" class="img-fluid" data-src="/images/logo-purple.png" src="/images/logo-purple.png" title="Free Web Hosting with PHP and MySQL"/>
#  </picture>
#  InfinityFree
#  </a>,
#  <a class="btn white" href="https://dash.infinityfree.com/login">Login</a>,
#  <a class="btn purple" href="https://dash.infinityfree.com/register">Register <img alt="-&gt;" class="img-fluid" src="/images/arrow.png"/></a>,
#  <a class="nav-link" href="/">Free Hosting</a>,
#  <a class="nav-link" href="/premium/">Premium Hosting</a>,
#  <a class="nav-link" href="/website-builder/">Website Builder</a>,
#  <a class="nav-link" href="https://forum.infinityfree.com/docs">Knowledge Base</a>,
#  <a class="nav-link" href="https://forum.infinityfree.com">Support Forum</a>,
# ...

# %%
hyper_references = soup.find_all('a')

# %%
links = []
for link in hyper_references:
  links.append(link.get('href'))
links
# Out:
# ['https://www.enable-javascript.com/',
#  '/',
#  'https://dash.infinityfree.com/login',
#  'https://dash.infinityfree.com/register',
#  '/',
#  '/premium/',
#  '/website-builder/',
#  'https://forum.infinityfree.com/docs',
#  'https://forum.infinityfree.com',
#  'https://dash.infinityfree.com/login',
#  'https://dash.infinityfree.com/register',
#  'https://dash.infinityfree.com/register',
#  'https://dash.infinityfree.com/register',
#  'https://forum.infinityfree.com/docs',
#  'https://forum.infinityfree.com/',
#  '/go/ifastnet',
#  '/go/sitepro',
#  '/go/spaceship',
#  '/contact/',
#  '/terms/',
#  '/privacy/',
#  '/responsible-disclosure/',
#  'https://dash.infinityfree.com/register',
#  '/go/ifastnet']
